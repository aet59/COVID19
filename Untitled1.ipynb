# %% [markdown]
# <a href="https://colab.research.google.com/github/aet59/COVID19/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x_train = np.load("x_train.npy")
y_train = np.load("y_train.npy")
x_test = np.load("x_test.npy")
y_test = np.load("y_test.npy")

plt.scatter(x_train, y_train, label="blue")
plt.scatter(x_test, y_test, label="orange")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def poly_features(x, degree):
  X_train_poly = poly_features(x_train, degree=3)
  X_test_poly = poly_features(x_test, degree=3)

  return np.vstack([x**i for i in range(degree+1)]).T

# %%
import numpy as np
import matplotlib.pyplot as plt

def poly_features(x, degree):
    x = x.reshape(-1, 1)
    return np.hstack([x**i for i in range(degree+1)])


def normal_equation(X, y):
    return np.linalg.solve(X.T @ X, X.T @ y)

def predict(X, theta):
    return X @ theta

def mean_squared_error(y_true, y_pred):
    return np.mean((y_true - y_pred.reshape(-1, 1))**2)

x_train = np.load("x_train.npy")
y_train = np.load("y_train.npy")
x_test = np.load("x_test.npy")
y_test = np.load("y_test.npy")

y_train = y_train.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)

degrees = [1, 2, 3, 4, 5]
mse_train = []
mse_test = []
plt.figure(figsize=(14, 4))

for i, degree in enumerate(degrees, 1):
    X_train_poly = poly_features(x_train, degree)
    X_test_poly = poly_features(x_test, degree)

    theta = normal_equation(X_train_poly, y_train)

    y_train_pred = predict(X_train_poly, theta)
    y_test_pred = predict(X_test_poly, theta)

    train_mse = mean_squared_error(y_train, y_train_pred)
    test_mse = mean_squared_error(y_test, y_test_pred)

    plt.subplot(1, len(degrees), i)
    plt.scatter(x_train, y_train, color='blue')
    plt.scatter(x_test, y_test, color='orange')

    x_curve = np.linspace(min(x_train), max(x_train), 200).reshape(-1, 1)
    X_curve_poly = poly_features(x_curve, degree)
    print(f"Shape of X_curve_poly: {X_curve_poly.shape}")
    print(f"Shape of theta: {theta.shape}")
    y_curve = X_curve_poly @ theta
    plt.plot(x_curve, y_curve, color="black", linewidth=2, label=f"Degree {degree}")

    plt.xlabel("x")
    plt.ylabel("y")
    plt.title(f"Degree {degree}")
    plt.legend()

    mse_train.append(train_mse)
    mse_test.append(test_mse)

plt.tight_layout()
plt.show()
# Out:
# Shape of X_curve_poly: (200, 2)
# Shape of theta: (2, 1)
# Shape of X_curve_poly: (200, 3)
# Shape of theta: (3, 1)
# Shape of X_curve_poly: (200, 4)
# Shape of theta: (4, 1)
# Shape of X_curve_poly: (200, 5)
# Shape of theta: (5, 1)
# Shape of X_curve_poly: (200, 6)
# Shape of theta: (6, 1)

# %% [markdown]
# Report:
#
# For this section, I started out with just uploading the data given in the zip and then after, plotting it where x would be red and y would be blue. after running, I saw that red(x) was a third degree negative polynomial and y seams more linear. I then tried to find a line that best fit the funtctions. Had to ensure the matrix were the same dimentions.
#
# The use of AI in this program come from Gemeni suggested fixes when encoutering run errors. A few of them were not helpful so I looked at stackoverflow for support as well.
